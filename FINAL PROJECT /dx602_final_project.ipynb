# %% [markdown]
# **DX602 Final Project**
# -----
#
# **Learning Objectives**
#
# In this project, you will complete an exploratory data analytics project using a dataset that you select from the options below.
#
# After completing this project, you will be able to:
#
# * Load a dataset into a Python notebook
# * Describe a dataset using descriptive statistics for both numerical and categorical variables
# * Create visualizations to show the range, spread, and categories of data values
# * Summarize categorical data using aggregate operations
# * Investigate relationships among variables using plots and descriptive statistics
# * Obtain and analyze a sample from a larger dataset
# * Apply linear regression to explore relationships between features and an outcome variable
#
# This is an **individual project**. No groups or teams are allowed.
#
# This project counts for **20% of your course grade**.
#
# __________
# **Warning about AI:**
#
# It is **strictly forbidden to use any generative AI (e.g., ChatGPT, Claude, Gemini, CoPilot or any similar tools)** to write solutions for any assignment. Students who submit work that is not authentically their own individual work will earn a grade of 0 on this assignment.
#
# **Note: Make sure to run all code from scratch before submitting or no credit will be given**
# _____
#
# **Dataset Options**
# -----
#
# Choose **one** dataset for your final project.
#
# **Option 1: Sports**
#
# Analyze sports performance data such as scores, shot attempts, shot percentages, or other game-related metrics.
#
#
# File to use: **`game_stats_v2.csv`**
#
# **Option 2: Environmental / Energy**
#
# Analyze environmental or energy-related variables such as energy consumption, temperature, emissions, or related trends over time.
#
#
# File to use: **`home_data_final.csv`**
#
# File to use:
#
# **Option 3: Outdoor Recreation**
#
# Analyze bike rentals patterns due to season, month, and weekday.
#
# File to use: **`bikes_final.csv`**
# ______
#
#
# **Project Requirements**
# -----
#
# Your project must be completed in a **Python notebook** using:
#
# * `pandas`
# * `matplotlib`
# * `sklearn`
#
# Your notebook must include the following:
#
# **1. Data Loading and Setup**
#
# * Load your dataset into the notebook
# * Show the first few rows
# * Inspect the structure of the data
# * Clean the data if needed
#
# **2. Descriptive Statistics**
# * Compute and present descriptive statistics for all relevant numerical columns
# * Summarize categorical columns where appropriate
#
# **3. Numeric Data Visualizations**
#
# Create charts that illustrate the distribution of numerical data, such as:
#
# * Histograms
# * Box plots
# * Bar charts (when appropriate)
#
# **4. Trends Over Time**
#
# * Use line charts to illustrate trends over time
# * Use standardized values when appropriate so multiple variables can be compared on the same scale
#
# **5. Categorical Data Analysis**
#
# * Show the distribution of one or more categorical variables
# * Use charts such as:
#     * Bar charts
#     * Pie charts
#
# **6. Grouped Analysis**
# * Group data by one or more categorical variables
# * Compute descriptive statistics for grouped data
# * Create charts to visualize grouped comparisons
#
# **7. New Feature / New Column**
#
# Create at least **one meaningful new column** for your analysis.
#
# Examples:
#
# * A ratio between two existing columns
# * A percentage
# * A standardized value relative to a base year or base category
#
# You must use this new column somewhere in your analysis.
#
# **8. Relationships Between Variables**
#
# * Investigate possible relationships between features
# * Use:
#     * Correlation or covariance statistics
#     * Scatter plots
#
# **9. Hypothesis**
#
# State a reasonable hypothesis about why a relationship might exist between two variables.
#
# **10. Linear Regression with `sklearn`**
#
# Use `sklearn` to build a **linear regression model** that attempts to explain a relationship between one outcome variable and one or more features.
#
# Your regression section must include:
#
# * A clear choice of predictor variable(s)
# * A clear outcome variable
# * Model fitting using `LinearRegression`
# * A plot showing predicted values compared to actual values
# * A regression line
#
# **11. Regression Discussion**
#
# Briefly explain:
#
# * What the regression results suggest
# * Whether the model does a good job explaining the relationship
# * Any limitations of the model
#
# **12. Code Quality and Reuse**
#
# Identify repetitive parts of your code and simplify them using:
#
# * Helper functions
# * Loops
# * Reusable code blocks
#
# **13. Something New**
#
# You must learn and apply **at least one skill that goes beyond class examples and homework**.
#
# Examples might include:
#
# * A new pandas technique
# * A more advanced matplotlib customization
# * A new type of grouping or transformation
# * A more polished plot layout
# ______________________________________________________
# **Deliverable**
# -----
#
# Submit a **well-structured Python notebook** (`.ipynb`).
#
# Your notebook must include:
#
# * All code used in your analysis
# * Charts and outputs
# * Markdown cells that explain each section
# * Clear organization and professional formatting
#
# __________________________________________________
# **Recommended Notebook Structure**
# -----
#
# Use the following structure to organize your notebook.
#
# **Section 1: Introduction**
#
# * Introduce the dataset you selected
# * State the purpose of your project
# * Describe the questions you want to investigate
#
# **Section 2: Load and Inspect the Data**
#
# * Import libraries
# * Load the dataset
# * Display sample rows
# * Check column names, data types, and missing values
#
# **Section 3: Data Cleaning and Preparation**
#
# * Handle missing values if needed
# * Rename columns if needed
# * Convert data types if needed
# * Create any cleaned versions of the data
#
# **Section 4: Descriptive Statistics**
#
# * Show summary statistics for numerical columns
# * Summarize important categorical columns
#
# **Section 5: Numerical Data Visualizations**
#
# * Create charts showing distributions
# * Explain what the charts reveal
#
# **Section 6: Categorical Data Analysis**
#
# * Create charts for categorical variables
# * Discuss the results
#
# **Section 7: Grouped Analysis**
#
# * Group by a meaningful category
# * Compute grouped summary statistics
# * Visualize grouped comparisons
#
# **Section 8: New Feature Engineering**
#
# * Create at least one new column
# * Explain why it is useful
# * Use it in a chart or summary
#
# **Section 9: Trends Over Time**
#
# * Plot one or more time-based trends
# * Include standardized values if useful for comparison
#
# **Section 10: Variable Relationships**
#
# * Compute correlation or covariance
# * Make scatter plots
# * Discuss possible relationships
#
# **Section 11: Hypothesis**
#
# * State your hypothesis about a relationship in the data
#
# **Section 12: Linear Regression**
#
# * Select features and outcome variable
# * Train the regression model
# * Display predictions vs. actual values
# * Plot the regression line
# * Interpret results
#
# **Section 13: Reflection / Conclusion**
#
# * Summarize your findings
# * Explain what you learned
# * Mention limitations and possible future improvements
#
# _________________________________________________________
# **Project Tips**
# -----
# * Make sure your charts are clearly labeled with:
#     * Title
#     * X-axis label
#     * Y-axis label
# * Write markdown explanations before or after each major code section
# * Keep your notebook clean and easy to follow
# * Use comments in code where helpful, but rely on markdown to explain the bigger picture
#
# ______________________________________________________
# **Final Reminder**
# -----
#
# Your final notebook should look like a polished project, not just a collection of code cells.
# Think of it as telling the story of your data analysis step by step.
# ______________________

# %%
# Imports 

import pandas as pd 
import matplotlib.pyplot as plt 
import sklearn

# %%
game_data = pd.read_csv('game_stats_v2.csv') # loading the data 

game_data.head(5) #sample rows 

game_data.columns # column names 

game_data.dtypes # data types 

game_data.isna().sum() # the number of NA values per column

game_data[game_data['home_team'].isna()] # looking at columns with NA values from above 
game_data = game_data.dropna()

game_data
# Out:
#           game_id         date_time_GMT            home_team  \
# 0      2016020045  2016-10-19T00:30:00Z   Chicago Blackhawks
# 1      2017020812  2018-02-07T00:00:00Z       Buffalo Sabres
# 2      2015020314  2015-11-24T01:00:00Z        Winnipeg Jets
# 3      2015020849  2016-02-17T00:00:00Z  Carolina Hurricanes
# 4      2017020586  2017-12-30T03:00:00Z        Anaheim Ducks
# ...           ...                   ...                  ...
# 23730  2018030413  2019-06-02T00:00:00Z       St Louis Blues
# 23731  2018030414  2019-06-04T00:00:00Z       St Louis Blues
# 23732  2018030415  2019-06-07T00:00:00Z        Boston Bruins
# 23733  2018030416  2019-06-10T00:00:00Z       St Louis Blues
# 23734  2018030417  2019-06-13T00:00:00Z        Boston Bruins
#
#                  away_team  home_won home_settled_in   home_head_coach  \
# 0      Philadelphia Flyers      True             REG  Joel Quenneville
# 1            Anaheim Ducks     False              OT      Phil Housley
# ...

# %%
game_data.info()
game_data.describe()
game_data['home_won'].value_counts() 
game_data.head(5) #sample rows 
game_data.select_dtypes(['bool','str'])# there are two columns that are categorical, away_won and home_won within the dataset (bool values)
# Out:
# <class 'pandas.DataFrame'>
# Index: 12646 entries, 0 to 23734
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   game_id                      12646 non-null  int64
#  1   date_time_GMT                12646 non-null  str
#  2   home_team                    12646 non-null  str
#  3   away_team                    12646 non-null  str
#  4   home_won                     12646 non-null  bool
#  5   home_settled_in              12646 non-null  str
#  6   home_head_coach              12646 non-null  str
#  7   home_goals                   12646 non-null  float64
#  8   home_shots                   12646 non-null  float64
#  9   home_hits                    12646 non-null  float64
#  10  home_pim                     12646 non-null  float64
#  11  home_powerPlayOpportunities  12646 non-null  float64
#  12  home_powerPlayGoals          12646 non-null  float64
# ...

# %%
# Histograms of columns 

cleaned_gamedata= game_data.drop(columns=['game_id']) # dropping the game ID column

axes = cleaned_gamedata.hist(figsize=(20, 20), bins=20)

for axe in axes.flatten(): 
    axe.set_ylabel('Frequency')
    axe.set_xlabel('Values')
plt.suptitle('Histograms of Game Data Columns')
plt.show()



# Plotting Average Goals in Home Vs Away Games 

avg_goals = {'Home': game_data['home_goals'].mean(),
             'Away': game_data['away_goals'].mean()}

plt.figure(figsize=(16, 8))
plt.bar(avg_goals.keys(), avg_goals.values())
plt.title('Average Goals in Home Vs Away Games')
plt.ylabel('Average Goals')
plt.xlabel('Game Type')


# Home vs Away Goals BoxPlot

home_goals = (game_data['home_goals']).dropna()
away_goals = (game_data['away_goals']).dropna()
plt.figure(figsize=(16, 8))
plt.boxplot([home_goals, away_goals])
plt.xticks([1, 2], ['Home Goals', 'Away Goals'])
plt.title('Distribution of Home vs Away Goals')
plt.ylabel('Goals')
plt.show()


# Home vs Away Goal Difference BoxPlot

game_data['goal_diff'] = game_data['home_goals'] - game_data['away_goals']

game_data.boxplot(column='goal_diff', figsize=(16, 8))
plt.title('Distribution of Goal Difference (Home - Away)')
plt.ylabel('Goal Difference')
plt.show()

# %%
game_data_categorical = game_data.select_dtypes(['bool', 'str'])

home_games_by_team = game_data_categorical['home_team'].value_counts()
away_games_by_team = game_data_categorical['away_team'].value_counts()
count_of_quarter_home_games_settled_in = game_data_categorical['home_settled_in'].value_counts()
count_of_quarter_away_games_settled_in = game_data_categorical['away_settled_in'].value_counts()

games_won = game_data_categorical[(game_data_categorical['away_won'] == True) | 
                                  (game_data_categorical['home_won']==True)] # this is the total games won in the season


games_lost = game_data_categorical[(game_data_categorical['away_won'] == False) | 
                                  (game_data_categorical['home_won']==False)]




game_data_categorical.columns
# Out:
# Index(['date_time_GMT', 'home_team', 'away_team', 'home_won',
#        'home_settled_in', 'home_head_coach', 'away_won', 'away_settled_in',
#        'away_head_coach'],
#       dtype='str')

# %%
# Stats Grouped By Team 

games_won_home = games_won[games_won['home_won'] == True].groupby('home_team').size()
games_won_away = games_won[games_won['away_won']==True].groupby( 'away_team').size() # the count of home won games 
games_lost_home = games_won[games_won['home_won']==False].groupby ('home_team').size()
games_lost_away= games_won[games_won['away_won']==False].groupby( 'away_team').size()
total_games_played_per_team = (
    games_won_home
    .add(games_won_away, fill_value=0)
    .add(games_lost_home, fill_value=0)
    .add(games_lost_away, fill_value=0)
)

# New Column Creations 
total_games_won_per_team = games_won_home + games_won_away
total_games_lost_per_team = games_lost_home + games_lost_away


average_home_goals_per_team = game_data.groupby('home_team')['home_goals'].mean()
average_away_goals_per_team = game_data.groupby('away_team')['away_goals'].mean()


# Adding New Columns to one Dataframe  
games_status_data_frame = pd.DataFrame({'Home Game Wins Count': games_won_home,
              'Away Games Win Count':games_won_away,
              'Games Lost Home':games_lost_home,
              'Games Lost Away':games_lost_away,
              'Total Games Won Per Team':total_games_won_per_team,
              'Total Games Lost Per Team':total_games_lost_per_team,
              'Total Games Played Per Team':total_games_played_per_team,
              'Home Win Percentage':(games_won_home/(games_won_home + games_lost_home)*100).round(2),
              'Home Loss Percentage':(games_lost_home/(games_won_home + games_lost_home)*100).round(2),
              'Away Win Percentage': (games_won_away/(games_won_away + games_lost_away)*100).round(2),
              'Away Loss Percentage': (games_lost_away/(games_won_away + games_lost_away)*100).round(2),
              'Average Home Goals Per Team':average_home_goals_per_team,
              'Average Away Goals Per Team':average_away_goals_per_team}) # this is the data 

games_status_data_frame = games_status_data_frame.reset_index()
games_status_data_frame = games_status_data_frame.rename(columns={'index': 'Team Name'})

games_status_data_frame


#Summary Statistics for Grouped/New Dataframe
games_status_data_frame.describe()
# Out:
#        Home Game Wins Count  Away Games Win Count  Games Lost Home  \
# count             33.000000             33.000000        33.000000
# mean             208.000000            175.212121       175.212121
# std               59.886351             51.018231        44.485080
# min               17.000000             17.000000        24.000000
# 25%              198.000000            163.000000       172.000000
# 50%              212.000000            187.000000       187.000000
# 75%              250.000000            204.000000       198.000000
# max              288.000000            243.000000       221.000000
#
#        Games Lost Away  Total Games Won Per Team  Total Games Lost Per Team  \
# count        33.000000                 33.000000                  33.000000
# mean        208.000000                383.212121                 383.212121
# std          51.229264                110.484942                  95.072590
# ...

# %%
# Plots of Grouped Stats

plot_df = games_status_data_frame.sort_values('Total Games Played Per Team', ascending=False)

plot_df.plot(
    x='Team Name',
    y=['Total Games Won Per Team', 'Total Games Lost Per Team'],
    kind='barh',
    figsize=(20,8),
    width = 0.8,
    color =['green','red'])

plt.title('Wins vs Losses by Team')
plt.xlabel('Count')
plt.ylabel('Team')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


plot_df = games_status_data_frame.sort_values('Home Win Percentage', ascending=False)

plot_df.plot(
    x='Team Name',
    y=['Home Win Percentage', 'Away Win Percentage'],
    kind='bar',
    figsize=(16,8),
    width = 0.8,
    color =['green','red'])
plt.title('Home Win % vs Away Win % by Team')
plt.xlabel('Team')
plt.ylabel('Win Percentage')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


plot_df = games_status_data_frame.sort_values('Total Games Played Per Team', ascending=False)
plot_df.plot(
    x='Team Name',
    y=['Total Games Won Per Team', 'Total Games Lost Per Team'],
    kind='bar',
    stacked=True,
    figsize=(16,8),
    width = 0.8,
    color = ['green','red'])
plt.title('Total Proportion of Games Won and Lost by Team')
plt.xlabel('Team')
plt.ylabel('Games')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


top10 = games_status_data_frame.sort_values('Total Games Won Per Team', ascending=False).head(10)

plt.figure(figsize=(16,8))
plt.barh(top10['Team Name'], top10['Total Games Won Per Team'])
plt.xticks(rotation=45)
plt.title('Top 10 Teams by Total Wins')
plt.xlabel('Wins')
plt.ylabel('Team')
plt.tight_layout()
plt.show()

# %%
# Time Series Data Analysis

game_data['date_time_GMT'] =pd.to_datetime(game_data['date_time_GMT']).dt.strftime('%Y-%m-%d') # converting to just a date for the datetime
game_data['Game Year'] =pd.to_datetime(game_data['date_time_GMT']).dt.strftime('%Y') # Extracting the year from the date for analysis


home_team_goals_by_year = game_data.groupby(['Game Year'])[['home_goals']].sum()
away_team_goals_by_year = game_data.groupby(['Game Year'])[['away_goals']].sum()
away_team_shots_by_year = game_data.groupby(['Game Year'])[['away_shots']].sum()
home_team_shots_by_year = game_data.groupby(['Game Year'])[['home_shots']].sum()

home_shots_scored = home_team_goals_by_year['home_goals'] / home_team_shots_by_year['home_shots']
away_shots_scored = away_team_goals_by_year['away_goals'] / away_team_shots_by_year['away_shots']




fig, axes = plt.subplots(1, 4, figsize=(25, 8))

home_team_goals_by_year.plot(kind='bar', ax=axes[0], label='Home Goals',width = 0.8, color = 'green')
axes[0].set_title('Home Goals Per Year')
axes[0].set_xlabel('Game Year')
axes[0].set_ylabel('Goals')
axes[0].tick_params(axis='x', labelrotation = 45)
axes[0].set_ylim(0, 5000)
axes[0].legend()

away_team_goals_by_year.plot(kind='bar', ax=axes[1], label='Away Goals',width = 0.8,color = 'green')
axes[1].set_title('Away Goals Per Year')
axes[1].set_xlabel('Game Year')
axes[1].set_ylabel('Goals')
axes[1].tick_params(axis='x', labelrotation = 45)
axes[1].set_ylim(0, 5000)
axes[1].legend()

home_team_shots_by_year.plot(kind='bar', ax=axes[2], label='Home Shots',width = 0.8, color = 'orange')
axes[2].set_title('Home Shots Per Year')
axes[2].set_xlabel('Game Year')
axes[2].tick_params(axis = 'x', labelrotation = 45)
axes[2].set_ylabel('Shots')
axes[2].set_ylim(0, 50000)
axes[2].legend()

away_team_shots_by_year.plot(kind='bar', ax=axes[3], label='Away Shots',width = 0.8,color = 'orange')
axes[3].set_title('Away Shots Per Year')
axes[3].set_xlabel('Game Year')
axes[3].set_ylabel('Shots')
axes[3].tick_params(axis='x', labelrotation = 45)
axes[3].set_ylim(0, 50000)
axes[3].legend()


conversion_df = pd.DataFrame({'Home Conversion Rate':home_shots_scored,
                              'Away Conversion Rate': away_shots_scored })

conversion_df.plot(kind= 'barh', figsize= (16,8),
    width = 0.8,
    color = ['green', 'orange'])

plt.title('Home vs Away Shot Conversion by Year (Goals / Shots)')
plt.xlabel('Conversion %')
plt.xticks(rotation = 45)
plt.ylabel('Game Year')
plt.xlim(0,0.12)
plt.show()
plt.show()


# Chicago Blackhawks and Boston Bruins Total Wins By Year

selected_games = game_data[
    game_data['home_team'].isin(['Chicago Blackhawks', 'Boston Bruins']) |
    game_data['away_team'].isin(['Chicago Blackhawks', 'Boston Bruins'])]

home_wins = selected_games.loc[
    selected_games['home_won'],
    ['home_team', 'Game Year']].rename(columns={'home_team': 'Team'}) # renaming to join the DF together and count a win as a win regardless of home or away

away_wins = selected_games.loc[
    selected_games['away_won'],
    ['away_team', 'Game Year']].rename(columns={'away_team': 'Team'}) # renaming to join the DF together and count a win as a win regardless of home or away

all_wins = pd.concat([home_wins, away_wins])

all_wins = all_wins[
    all_wins['Team'].isin(['Chicago Blackhawks', 'Boston Bruins'])]

wins_by_year = all_wins.groupby(['Game Year', 'Team']).size().unstack(fill_value=0)

wins_by_year.plot(kind='line', marker='o', figsize= (16,8), color = ['gold','red'])
plt.title('Wins by Year: Chicago Blackhawks vs Boston Bruins')
plt.xlabel('Game Year')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45)
plt.legend(title='Team')
plt.tight_layout()
plt.show()

# %%
# Correlation and Scatter Plots 

game_data.corr(numeric_only=True).abs() # Correlation Matrix of Numeric Columns 

corr_matrix = game_data.corr(numeric_only=True).abs()

corr_pairs = corr_matrix.unstack()
corr_pairs = corr_pairs[corr_pairs < 1]   # remove self-correlations
corr_pairs = corr_pairs.sort_values(ascending=False)

print(corr_pairs.head(10))

games_status_data_frame.corr(numeric_only=True).abs() # viewing the correlation of the data by team
# Out:
# away_won                   home_won                     1.000000
# home_won                   away_won                     1.000000
# home_faceOffWinPercentage  away_faceOffWinPercentage    1.000000
# away_faceOffWinPercentage  home_faceOffWinPercentage    1.000000
# goal_diff                  home_won                     0.820267
# home_won                   goal_diff                    0.820267
# away_won                   goal_diff                    0.820267
# goal_diff                  away_won                     0.820267
# home_goals                 goal_diff                    0.741976
# goal_diff                  home_goals                   0.741976
# dtype: float64
#                              Home Game Wins Count  Away Games Win Count  \
# Home Game Wins Count                     1.000000              0.984796
# Away Games Win Count                     0.984796              1.000000
# Games Lost Home                          0.644472              0.668243
# ...
